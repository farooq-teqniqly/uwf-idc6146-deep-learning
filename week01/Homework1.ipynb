# %% [markdown]
# ### 1. Name string

# %%
first_name = 'Farooq' # type in your first name here
first_name
# Out:
# 'Farooq'

# %%
last_name = 'Mahmud' # type in your last name here
last_name
# Out:
# 'Mahmud'

# %% [markdown]
# #### Please concatenate your first and last name with a space between them, then print your name

# %%
# Please concatenate your first and last name with a space between them, then print your name
full_name = first_name + ' ' + last_name
full_name
# Out:
# 'Farooq Mahmud'

# %% [markdown]
# ### 2. Given the following list, write a program to display the first and last colors

# %%
# Given the following list, write a program to display the first and last colors
color_list = ["Red","Green","White" ,"Black"]

def first_and_last_colors(colors: list) -> list:
    return [colors[0], colors[-1]]

first_and_last_colors(color_list)
# Out:
# ['Red', 'Black']

# %% [markdown]
# ### 3. Compute and print the value of `n+nn+nnn`.

# %%
# Compute and print the value of n+nn+nnn.
n = 5
result = n + (n*n) + (n*n*n)
result
# Out:
# 155

# %% [markdown]
# ### 4. Numbers

# %% [markdown]
# ### 4.1 Calculate `num = 1325 / 3`

# %%
num = 1325/3
num
# Out:
# 441.6666666666667

# %% [markdown]
# ### 4.2 Round `num` to 3 decimals

# %%
num = round(num, 3)
num
# Out:
# 441.667

# %% [markdown]
# ### 4.3 Return the remainder of `num`

# %%
remainder = num % 2
remainder
# Out:
# 1.6669999999999732

# %% [markdown]
# ### 4.4 Compute `num` to the power of 3

# %%
num = pow(num, 3)
num
# Out:
# 86155866.36588794

# %% [markdown]
# ### 5. Lists

# %%
num1 = [386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345,
    399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217]
num2 = [815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717,
    958,743, 527]
# Out:
# 32
# 20

# %% [markdown]
# ### 5.1 Concatenate `num1` and `num2` to new list `num_new`

# %%
num_new = num1 + num2
num_new
# Out:
# [386,
#  462,
#  47,
#  418,
#  907,
#  344,
#  236,
#  375,
#  823,
#  566,
#  597,
#  978,
#  328,
#  615,
#  953,
#  345,
#  399,
#  162,
#  758,
#  219,
#  918,
#  237,
#  412,
#  566,
#  826,
#  248,
#  866,
#  950,
#  626,
#  949,
#  687,
#  217,
#  815,
#  67,
#  104,
#  58,
#  512,
#  24,
#  892,
#  894,
#  767,
#  553,
#  81,
#  379,
#  843,
#  831,
#  445,
#  742,
#  717,
#  958,
#  743,
#  527]

# %% [markdown]
# ### 5.2 Print the length of list `num_new`

# %%
print(len(num_new))
# Out:
# 52

# %% [markdown]
# ### 5.3 Add the cube of `10` at the end of the list `num_new`

# %%
num_new.append(pow(10, 3))
num_new[-1]
# Out:
# 1000

# %% [markdown]
# ### 5.4 Print the length of list `num_new` again

# %%
print(len(num_new))
# Out:
# 53

# %% [markdown]
# ### 5.5 Write a Python program to print all even numbers in list `num_new` and stop printing any after `237` in the sequence.

# %% [markdown]
# ### 6 More examples of Python code can be found at https://www.geeksforgeeks.org/python-cheat-sheet/
# Please practice more if you are new to Python.

# %%
numbers = [num for num in num_new if num % 2 == 0 and num <= 237]
numbers
# Out:
# [236, 162, 104, 58, 24]
